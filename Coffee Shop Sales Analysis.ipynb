# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import calendar

# %%
df = pd.read_excel('../brewediq/CoffeeShopSales.xlsx')

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.dtypes
# Out:
# transaction_id               int64
# transaction_date    datetime64[ns]
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location              object
# product_id                   int64
# unit_price                 float64
# product_category            object
# product_type                object
# product_detail              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# dtype: int64

# %%
df.transaction_id.value_counts()
# Out:
# transaction_id
# 1         1
# 99641     1
# 99661     1
# 99662     1
# 99663     1
#          ..
# 49812     1
# 49813     1
# 49814     1
# 49815     1
# 149456    1
# Name: count, Length: 149116, dtype: int64

# %%
df.store_location.unique()
# Out:
# array(['Lower Manhattan', "Hell's Kitchen", 'Astoria'], dtype=object)

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
# ...

# %%
df.product_category.count()
# Out:
# 149116

# %%
df.product_category.unique()
# Out:
# array(['Coffee', 'Tea', 'Drinking Chocolate', 'Bakery', 'Flavours',
#        'Loose Tea', 'Coffee beans', 'Packaged Chocolate', 'Branded'],
#       dtype=object)

# %%
e=df.groupby('product_type')['unit_price'].sum()
e
# Out:
# product_type
# Barista Espresso         59956.25
# Biscotti                 19528.78
# Black tea                 2711.85
# Brewed Black tea         31152.00
# Brewed Chai tea          50466.35
# Brewed Green tea         15552.50
# Brewed herbal tea        30864.50
# Chai tea                  4301.25
# Clothing                  6163.00
# Drinking Chocolate        2728.04
# Drip coffee              21065.00
# Espresso Beans            5560.25
# Gourmet Beans             6798.00
# Gourmet brewed coffee    45605.60
# Green beans               1340.00
# Green tea                 1470.75
# Herbal tea                2729.75
# Hot chocolate            47578.75
# House blend Beans         3294.00
# Housewares                7074.00
# Organic Beans             8419.50
# Organic Chocolate         1679.60
# Organic brewed coffee    24601.30
# Pastry                   25477.49
# Premium Beans            11433.50
# Premium brewed coffee    25401.15
# Regular syrup             3983.20
# ...

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['sales'] = df['transaction_qty'] * df['unit_price']

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.groupby('transaction_date')['sales'].sum()
# Out:
# transaction_date
# 2023-01-01    2508.20
# 2023-01-02    2403.35
# 2023-01-03    2565.00
# 2023-01-04    2220.10
# 2023-01-05    2418.85
#                ...
# 2023-06-26    5875.90
# 2023-06-27    5975.65
# 2023-06-28    4728.90
# 2023-06-29    4450.75
# 2023-06-30    5481.32
# Name: sales, Length: 181, dtype: float64

# %%
df.store_location.unique()
# Out:
# array(['Lower Manhattan', "Hell's Kitchen", 'Astoria'], dtype=object)

# %%
hell = df[df.store_location =="Hell's Kitchen"]
hell
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 17                  18       2023-01-01         08:00:18                1
# 18                  19       2023-01-01         08:00:39                2
# 19                  20       2023-01-01         08:11:45                1
# 20                  21       2023-01-01         08:17:27                2
# 23                  24       2023-01-01         08:29:38                1
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id  store_location  product_id  unit_price    product_category  \
# ...

# %%
lm = df[df.store_location =="Lower Manhattan"]
lm
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149045          149386       2023-06-30         18:28:56                2
# 149046          149387       2023-06-30         18:30:02                1
# 149047          149388       2023-06-30         18:30:02                1
# 149094          149435       2023-06-30         19:40:09                2
# 149110          149451       2023-06-30         20:16:31                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
a = df[df.store_location =="Astoria"]
a
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 105                106       2023-01-01         11:01:48                1
# 106                107       2023-01-01         11:01:58                1
# 107                108       2023-01-01         11:01:58                1
# 111                112       2023-01-01         11:08:11                1
# 113                114       2023-01-01         11:09:01                1
# ...                ...              ...              ...              ...
# 149103          149444       2023-06-30         19:51:59                2
# 149104          149445       2023-06-30         19:52:28                2
# 149105          149446       2023-06-30         19:53:46                1
# 149107          149448       2023-06-30         19:57:49                2
# 149108          149449       2023-06-30         19:57:49                1
#
#         store_id store_location  product_id  unit_price    product_category  \
# ...

# %% [markdown]
# ## In below code shows that the sum of sales in the data

# %%
df.sales.sum()
# Out:
# 698812.3300000002

# %% [markdown]
# ## shows that transaction id is unique in the data

# %%
df.transaction_id.nunique()
# Out:
# 149116

# %%
df.sales.mean()
# Out:
# 4.686367190643527

# %%
df.transaction_qty.mean()
# Out:
# 1.438276241315486

# %%
sales_revenueM = df.groupby(df['transaction_date'].dt.to_period('M'))['sales'].sum()
sales_revenueM
# Out:
# transaction_date
# 2023-01     81677.74
# 2023-02     76145.19
# 2023-03     98834.68
# 2023-04    118941.08
# 2023-05    156727.76
# 2023-06    166485.88
# Freq: M, Name: sales, dtype: float64

# %%
sales_revenueM.plot(kind='bar',color=['teal','tomato'])
plt.title('MONTHLY REVENUE')
plt.xlabel('Transaction Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
sales_revenueW = df.groupby(df['transaction_date'].dt.to_period('W'))['sales'].sum()
sales_revenueW
# Out:
# transaction_date
# 2022-12-26/2023-01-01     2508.20
# 2023-01-02/2023-01-08    17139.33
# 2023-01-09/2023-01-15    19129.53
# 2023-01-16/2023-01-22    19818.51
# 2023-01-23/2023-01-29    18271.63
# 2023-01-30/2023-02-05    17231.59
# 2023-02-06/2023-02-12    18333.35
# 2023-02-13/2023-02-19    19856.62
# 2023-02-20/2023-02-26    20063.07
# 2023-02-27/2023-03-05    20389.75
# 2023-03-06/2023-03-12    22146.34
# 2023-03-13/2023-03-19    23594.59
# 2023-03-20/2023-03-26    23395.30
# 2023-03-27/2023-04-02    22055.55
# 2023-04-03/2023-04-09    26079.89
# 2023-04-10/2023-04-16    28981.30
# 2023-04-17/2023-04-23    29217.51
# 2023-04-24/2023-04-30    27386.63
# 2023-05-01/2023-05-07    32110.10
# 2023-05-08/2023-05-14    36056.88
# 2023-05-15/2023-05-21    38476.55
# 2023-05-22/2023-05-28    36605.12
# 2023-05-29/2023-06-04    33914.41
# 2023-06-05/2023-06-11    37457.26
# 2023-06-12/2023-06-18    41315.94
# 2023-06-19/2023-06-25    40764.86
# 2023-06-26/2023-07-02    26512.52
# ...

# %%
sales_revenueW.plot(kind='bar',color=['teal','tomato'])
plt.title('WEEK REVENUE')
plt.xlabel('Transaction Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
sales_revenueD = df.groupby(df['transaction_date'].dt.to_period('D'))['sales'].sum()
sales_revenueD
# Out:
# transaction_date
# 2023-01-01    2508.20
# 2023-01-02    2403.35
# 2023-01-03    2565.00
# 2023-01-04    2220.10
# 2023-01-05    2418.85
#                ...
# 2023-06-26    5875.90
# 2023-06-27    5975.65
# 2023-06-28    4728.90
# 2023-06-29    4450.75
# 2023-06-30    5481.32
# Freq: D, Name: sales, Length: 181, dtype: float64

# %%
sales_revenueD.plot(kind='line')
plt.title('DAILY REVENUE')
plt.xlabel('Transaction Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## The observation shows that groupby transaction date with Month data

# %%
Month_data=df.groupby(df.transaction_date.dt.to_period('M')).size()
Month_data
# Out:
# transaction_date
# 2023-01    17314
# 2023-02    16359
# 2023-03    21229
# 2023-04    25335
# 2023-05    33527
# 2023-06    35352
# Freq: M, dtype: int64

# %%
Month_data.plot(kind='line',color='tomato')
# Out:
# <Axes: xlabel='transaction_date'>

# %% [markdown]
# ## The observation shows that groupby transaction date with Week data

# %%
Week_data=df.groupby(df.transaction_date.dt.to_period('W')).size()
Week_data
# Out:
# transaction_date
# 2022-12-26/2023-01-01     550
# 2023-01-02/2023-01-08    3825
# 2023-01-09/2023-01-15    4113
# 2023-01-16/2023-01-22    4029
# 2023-01-23/2023-01-29    3854
# 2023-01-30/2023-02-05    3761
# 2023-02-06/2023-02-12    4005
# 2023-02-13/2023-02-19    4263
# 2023-02-20/2023-02-26    4099
# 2023-02-27/2023-03-05    4517
# 2023-03-06/2023-03-12    4786
# 2023-03-13/2023-03-19    5049
# 2023-03-20/2023-03-26    4825
# 2023-03-27/2023-04-02    4858
# 2023-04-03/2023-04-09    5703
# 2023-04-10/2023-04-16    6205
# 2023-04-17/2023-04-23    5942
# 2023-04-24/2023-04-30    5853
# 2023-05-01/2023-05-07    7224
# 2023-05-08/2023-05-14    7769
# 2023-05-15/2023-05-21    8014
# 2023-05-22/2023-05-28    7610
# 2023-05-29/2023-06-04    7477
# 2023-06-05/2023-06-11    8145
# 2023-06-12/2023-06-18    8594
# 2023-06-19/2023-06-25    8400
# 2023-06-26/2023-07-02    5646
# Freq: W-SUN, dtype: int64

# %%
Week_data.plot(kind='bar',figsize=(8,5),color=['teal','tomato'])
# Out:
# <Axes: xlabel='transaction_date'>

# %% [markdown]
# ## The observation shows that groupby transaction date with Date data

# %%
Date_data=df.groupby(df.transaction_date.dt.to_period('D')).size()
Date_data
# Out:
# transaction_date
# 2023-01-01     550
# 2023-01-02     566
# 2023-01-03     582
# 2023-01-04     497
# 2023-01-05     547
#               ...
# 2023-06-26    1195
# 2023-06-27    1277
# 2023-06-28    1070
# 2023-06-29    1009
# 2023-06-30    1095
# Freq: D, Length: 181, dtype: int64

# %%
Date_data.plot(kind='line',color='tomato')
# Out:
# <Axes: xlabel='transaction_date'>

# %% [markdown]
# ## Daily Moving Average gives the per Month or Week or Day

# %%
Sales = df.groupby(df.transaction_date.dt.to_period('W'))['sales'].sum()
mov_avg = Sales.rolling(window=2).mean()

# %%
mov_avg
# Out:
# transaction_date
# 2022-12-26/2023-01-01          NaN
# 2023-01-02/2023-01-08     9823.765
# 2023-01-09/2023-01-15    18134.430
# 2023-01-16/2023-01-22    19474.020
# 2023-01-23/2023-01-29    19045.070
# 2023-01-30/2023-02-05    17751.610
# 2023-02-06/2023-02-12    17782.470
# 2023-02-13/2023-02-19    19094.985
# 2023-02-20/2023-02-26    19959.845
# 2023-02-27/2023-03-05    20226.410
# 2023-03-06/2023-03-12    21268.045
# 2023-03-13/2023-03-19    22870.465
# 2023-03-20/2023-03-26    23494.945
# 2023-03-27/2023-04-02    22725.425
# 2023-04-03/2023-04-09    24067.720
# 2023-04-10/2023-04-16    27530.595
# 2023-04-17/2023-04-23    29099.405
# 2023-04-24/2023-04-30    28302.070
# 2023-05-01/2023-05-07    29748.365
# 2023-05-08/2023-05-14    34083.490
# 2023-05-15/2023-05-21    37266.715
# 2023-05-22/2023-05-28    37540.835
# 2023-05-29/2023-06-04    35259.765
# 2023-06-05/2023-06-11    35685.835
# 2023-06-12/2023-06-18    39386.600
# 2023-06-19/2023-06-25    41040.400
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(Sales.index.astype(str),Sales.values,color='teal')
plt.plot(mov_avg.index.astype(str),mov_avg.values,color='tomato')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Month over Month growth for sales

# %%
Sales = df.groupby(df.transaction_date.dt.to_period('M'))['sales'].sum()
daily_growth = Sales.pct_change() * 100
daily_growth
# Out:
# transaction_date
# 2023-01          NaN
# 2023-02    -6.773633
# 2023-03    29.797667
# 2023-04    20.343466
# 2023-05    31.769242
# 2023-06     6.226159
# Freq: M, Name: sales, dtype: float64

# %%
daily_growth.plot(kind='bar',figsize=(10,5),color=['teal','tomato'])
plt.title('MONTHLY GROWTH')
plt.xlabel('Transaction Date')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## 3 Module

# %%
store_sales = df.groupby('store_location')['sales'].sum()
store_sales.plot(kind='barh',color=['teal','tomato'])
# Out:
# <Axes: ylabel='store_location'>

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df["sales"] = df["transaction_qty"] * df["unit_price"]
total_sales = df["sales"].sum()

# %%
df.groupby('transaction_date')['store_location'].sum()
# Out:
# transaction_date
# 2023-01-01    Lower ManhattanLower ManhattanLower ManhattanL...
# 2023-01-02    Lower ManhattanLower ManhattanLower ManhattanL...
# 2023-01-03    Lower ManhattanLower ManhattanLower ManhattanL...
# 2023-01-04    Lower ManhattanLower ManhattanLower ManhattanL...
# 2023-01-05    Lower ManhattanLower ManhattanLower ManhattanL...
#                                     ...
# 2023-06-26    Lower ManhattanLower ManhattanLower ManhattanL...
# 2023-06-27    AstoriaLower ManhattanAstoriaLower ManhattanLo...
# 2023-06-28    AstoriaAstoriaLower ManhattanAstoriaLower Manh...
# 2023-06-29    AstoriaAstoriaAstoriaAstoriaAstoriaAstoriaAsto...
# 2023-06-30    Lower ManhattanLower ManhattanLower ManhattanL...
# Name: store_location, Length: 181, dtype: object

# %%
df.groupby('store_location')['unit_price'].mean()
# Out:
# store_location
# Astoria            3.384897
# Hell's Kitchen     3.394218
# Lower Manhattan    3.366643
# Name: unit_price, dtype: float64

# %%
df.groupby('store_location')['transaction_qty'].mean()
# Out:
# store_location
# Astoria            1.403012
# Hell's Kitchen     1.413955
# Lower Manhattan    1.501444
# Name: transaction_qty, dtype: float64

# %%
y = df.groupby([df['transaction_date'].dt.to_period('M'),'store_location']).size().reset_index(name='count')

# Convert Period to Timestamp for plotting
y['transaction_date'] = y['transaction_date'].dt.to_timestamp()

plt.figure(figsize=(20, 6))
for category in y['store_location'].unique():
    subset = y[y['store_location'] == category]
    plt.plot(subset['transaction_date'], subset['count'], label=category, marker='o')

plt.xlabel("Transaction Date")
plt.ylabel("Count")
plt.title("Store Transaction Trends")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
store1= hell.groupby(hell.transaction_date.dt.to_period('M'))["sales"].sum()
display(store1)
store2= lm.groupby(lm.transaction_date.dt.to_period('M'))["sales"].sum()
display(store2)
store3= a.groupby(a.transaction_date.dt.to_period('M'))["sales"].sum()
display(store3)
# Out:
# transaction_date
# 2023-01    27820.65
# 2023-02    25719.80
# 2023-03    33110.57
# 2023-04    40304.14
# 2023-05    52598.93
# 2023-06    56957.08
# Freq: M, Name: sales, dtype: float64
# transaction_date
# 2023-01    26543.43
# 2023-02    25320.05
# 2023-03    32888.68
# 2023-04    39159.33
# 2023-05    51700.07
# 2023-06    54445.69
# Freq: M, Name: sales, dtype: float64
# transaction_date
# 2023-01    27313.66
# 2023-02    25105.34
# 2023-03    32835.43
# 2023-04    39477.61
# 2023-05    52428.76
# 2023-06    55083.11
# Freq: M, Name: sales, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(store1.index.astype(str),store1.values, label="Hell's Kitchen",color='teal')
plt.plot(store2.index.astype(str),store2.values, label="Lower Manhattan",color='tomato')
plt.plot(store3.index.astype(str),store3.values, label="Astoria",color='navy')
plt.legend()
plt.show()

# %%
rt=df[df.transaction_date.dt.strftime('%B')=="Hell's Kitchen"]
Sales= rt.groupby(rt.transaction_date.dt.to_period('D'))['sales'].sum()
monthly_growth = Sales.pct_change()*100
monthly_growth
# Out:
# Series([], Freq: D, Name: sales, dtype: float64)

# %%
monthly_data = df.groupby(df.transaction_date.dt.to_period('M')).size()
display(monthly_data)
monthly_data.plot(kind='bar',color=['teal','tomato'])
# Out:
# transaction_date
# 2023-01    17314
# 2023-02    16359
# 2023-03    21229
# 2023-04    25335
# 2023-05    33527
# 2023-06    35352
# Freq: M, dtype: int64
# <Axes: xlabel='transaction_date'>

# %%
hsale = hell.groupby(hell.transaction_date.dt.to_period('M'))['sales'].sum()
hmonthly_growth = hsale.pct_change()*100
hmonthly_growth
# Out:
# transaction_date
# 2023-01          NaN
# 2023-02    -7.551405
# 2023-03    28.735721
# 2023-04    21.725902
# 2023-05    30.505030
# 2023-06     8.285625
# Freq: M, Name: sales, dtype: float64

# %%
hmonthly_growth.plot(kind='bar',figsize=(10,5),color=['teal','tomato'])
# Out:
# <Axes: xlabel='transaction_date'>

# %%
lmsale = lm.groupby(lm.transaction_date.dt.to_period('M'))['sales'].sum()
lmmonthly_growth = lmsale.pct_change()*100
lmmonthly_growth
# Out:
# transaction_date
# 2023-01          NaN
# 2023-02    -4.608975
# 2023-03    29.891845
# 2023-04    19.066287
# 2023-05    32.024910
# 2023-06     5.310670
# Freq: M, Name: sales, dtype: float64

# %%
lmmonthly_growth.plot(kind='bar',figsize=(10,5),color=['teal','tomato'])
# Out:
# <Axes: xlabel='transaction_date'>

# %%
asale = a.groupby(a.transaction_date.dt.to_period('M'))['sales'].sum()
amonthly_growth = asale.pct_change()*100
amonthly_growth
# Out:
# transaction_date
# 2023-01          NaN
# 2023-02    -8.085039
# 2023-03    30.790621
# 2023-04    20.228698
# 2023-05    32.806317
# 2023-06     5.062775
# Freq: M, Name: sales, dtype: float64

# %%
amonthly_growth.plot(kind='bar',figsize=(10,5),color=['teal','tomato'])
# Out:
# <Axes: xlabel='transaction_date'>

# %% [markdown]
# ## 4 Module

# %% [markdown]
# ##

# %%
category_salesS = df.groupby('product_category')['sales'].sum().reset_index()
plt.figure(figsize=(8,5))
plt.bar(category_salesS['product_category'], category_salesS['sales'],color=['teal','tomato'])
plt.title("Product Category Distribution (by Sales)")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
Category_distribution = df.groupby('product_category')['transaction_qty'].sum().reset_index()
plt.figure(figsize=(6,4))
plt.bar(Category_distribution['product_category'], Category_distribution['transaction_qty'],color=['teal','tomato'])
plt.title("Product Category Distribution (by Sales)")
plt.title("Product Category Distribution (by Sold Quantities)")
plt.xlabel("Product Category")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=80)
plt.show()

# %%
category_sales2 = df.groupby(['product_category','product_type'])['sales'].sum().reset_index()
plt.figure(figsize=(8,5))
plt.bar(category_salesS['product_category'], category_salesS['sales'],color=['teal','tomato'])
plt.title("Product Category Distribution (by Sales)")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
Category_distribution = df.groupby(['product_category','product_type'])['transaction_qty'].sum().reset_index()
plt.figure(figsize=(6,4))
plt.bar(Category_distribution['product_category'], Category_distribution['transaction_qty'],color=['teal','tomato'])
plt.title("Product Category Distribution (by Sales)")
plt.title("Product Category Distribution (by Sold Quantities)")
plt.xlabel("Product Category")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=60)
plt.show()

# %%
top_selling = df.groupby('product_type')['sales'].sum().nlargest().reset_index()
top_selling
# Out:
#             product_type     sales
# 0       Barista Espresso  91406.20
# 1        Brewed Chai tea  77081.95
# 2          Hot chocolate  72416.00
# 3  Gourmet brewed coffee  70034.60
# 4       Brewed Black tea  47932.00

# %%
top_selling = df.groupby('product_type')['transaction_qty'].sum().nlargest().reset_index()
top_selling
# Out:
#             product_type  transaction_qty
# 0        Brewed Chai tea            26250
# 1  Gourmet brewed coffee            25973
# 2       Barista Espresso            24943
# 3       Brewed Black tea            17462
# 4          Hot chocolate            17457

# %%
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%H:%M:%S')

# %%
df
# Out:
#         transaction_id transaction_date    transaction_time  transaction_qty  \
# 0                    1       2023-01-01 1900-01-01 07:06:11                2
# 1                    2       2023-01-01 1900-01-01 07:08:56                2
# 2                    3       2023-01-01 1900-01-01 07:14:04                2
# 3                    4       2023-01-01 1900-01-01 07:20:24                1
# 4                    5       2023-01-01 1900-01-01 07:22:41                2
# ...                ...              ...                 ...              ...
# 149111          149452       2023-06-30 1900-01-01 20:18:41                2
# 149112          149453       2023-06-30 1900-01-01 20:25:10                2
# 149113          149454       2023-06-30 1900-01-01 20:31:34                1
# 149114          149455       2023-06-30 1900-01-01 20:57:19                1
# 149115          149456       2023-06-30 1900-01-01 20:57:19                2
#
# ...

# %% [markdown]
# ## Daily Analysis

# %%
df['week_name']= df['transaction_date'].dt.day_name()
df
# Out:
#         transaction_id transaction_date    transaction_time  transaction_qty  \
# 0                    1       2023-01-01 1900-01-01 07:06:11                2
# 1                    2       2023-01-01 1900-01-01 07:08:56                2
# 2                    3       2023-01-01 1900-01-01 07:14:04                2
# 3                    4       2023-01-01 1900-01-01 07:20:24                1
# 4                    5       2023-01-01 1900-01-01 07:22:41                2
# ...                ...              ...                 ...              ...
# 149111          149452       2023-06-30 1900-01-01 20:18:41                2
# 149112          149453       2023-06-30 1900-01-01 20:25:10                2
# 149113          149454       2023-06-30 1900-01-01 20:31:34                1
# 149114          149455       2023-06-30 1900-01-01 20:57:19                1
# 149115          149456       2023-06-30 1900-01-01 20:57:19                2
#
# ...

# %%
daily_analysis = df.groupby([df['transaction_date'].dt.date,'week_name'])['sales'].sum().reset_index()
daily_analysis
# Out:
#     transaction_date  week_name    sales
# 0         2023-01-01     Sunday  2508.20
# 1         2023-01-02     Monday  2403.35
# 2         2023-01-03    Tuesday  2565.00
# 3         2023-01-04  Wednesday  2220.10
# 4         2023-01-05   Thursday  2418.85
# ..               ...        ...      ...
# 176       2023-06-26     Monday  5875.90
# 177       2023-06-27    Tuesday  5975.65
# 178       2023-06-28  Wednesday  4728.90
# 179       2023-06-29   Thursday  4450.75
# 180       2023-06-30     Friday  5481.32
#
# [181 rows x 3 columns]

# %%
Avg_daily_analysis = daily_analysis.groupby('week_name')['sales'].mean()
Avg_daily_analysis = Avg_daily_analysis.reindex(list(calendar.day_name))
Avg_daily_analysis
# Out:
# week_name
# Monday       3910.664615
# Tuesday      3825.228462
# Wednesday    3858.213077
# Thursday     3875.683846
# Friday       3898.961538
# Saturday     3875.779200
# Sunday       3781.935000
# Name: sales, dtype: float64

# %%
plt.figure(figsize=(9,6))
plt.bar(Avg_daily_analysis.index,Avg_daily_analysis.values,color=['teal','tomato'])
plt.title('Avg_daily_analysis')
plt.xlabel('week_name')
plt.ylabel('sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Time Analysis

# %%
Monday_data = df[df['transaction_date'].dt.day_name() == 'Monday']
Monday_data
# Out:
#         transaction_id transaction_date    transaction_time  transaction_qty  \
# 550                551       2023-01-02 1900-01-01 07:01:59                1
# 551                552       2023-01-02 1900-01-01 07:12:05                1
# 552                553       2023-01-02 1900-01-01 07:16:35                2
# 553                554       2023-01-02 1900-01-01 07:16:46                1
# 554                555       2023-01-02 1900-01-01 07:16:46                1
# ...                ...              ...                 ...              ...
# 144660          144997       2023-06-26 1900-01-01 19:51:59                2
# 144661          144998       2023-06-26 1900-01-01 19:54:52                1
# 144662          144999       2023-06-26 1900-01-01 19:55:17                1
# 144663          145000       2023-06-26 1900-01-01 19:55:48                2
# 144664          145001       2023-06-26 1900-01-01 19:57:58                2
#
# ...

# %%
df['Hour']= pd.to_datetime(df.transaction_time).dt.hour
df
# Out:
#         transaction_id transaction_date    transaction_time  transaction_qty  \
# 0                    1       2023-01-01 1900-01-01 07:06:11                2
# 1                    2       2023-01-01 1900-01-01 07:08:56                2
# 2                    3       2023-01-01 1900-01-01 07:14:04                2
# 3                    4       2023-01-01 1900-01-01 07:20:24                1
# 4                    5       2023-01-01 1900-01-01 07:22:41                2
# ...                ...              ...                 ...              ...
# 149111          149452       2023-06-30 1900-01-01 20:18:41                2
# 149112          149453       2023-06-30 1900-01-01 20:25:10                2
# 149113          149454       2023-06-30 1900-01-01 20:31:34                1
# 149114          149455       2023-06-30 1900-01-01 20:57:19                1
# 149115          149456       2023-06-30 1900-01-01 20:57:19                2
#
# ...

# %%
hour_analysis = df.groupby([df.transaction_date.dt.date,'Hour'])['sales'].sum().reset_index()
hour_analysis
# Out:
#      transaction_date  Hour   sales
# 0          2023-01-01     7   81.05
# 1          2023-01-01     8   85.90
# 2          2023-01-01     9  186.35
# 3          2023-01-01    10  127.35
# 4          2023-01-01    11  236.25
# ...               ...   ...     ...
# 2507       2023-06-30    16  185.30
# 2508       2023-06-30    17  221.45
# 2509       2023-06-30    18  208.90
# 2510       2023-06-30    19  195.95
# 2511       2023-06-30    20   32.35
#
# [2512 rows x 3 columns]

# %%
avg_hourly_analysis = hour_analysis.groupby('Hour')['sales'].mean()
avg_hourly_analysis
# Out:
# Hour
# 6     210.579519
# 7     350.974972
# 8     456.905359
# 9     470.549890
# 10    489.908232
# 11    255.906851
# 12    222.059613
# 13    223.024586
# 14    228.202983
# 15    230.569613
# 16    227.197514
# 17    221.736519
# 18    189.426519
# 19    157.163978
# 20     53.375273
# Name: sales, dtype: float64

# %%
Monday_data.transaction_date.unique().tolist()
# Out:
# [Timestamp('2023-01-02 00:00:00'),
#  Timestamp('2023-01-09 00:00:00'),
#  Timestamp('2023-01-16 00:00:00'),
#  Timestamp('2023-01-23 00:00:00'),
#  Timestamp('2023-01-30 00:00:00'),
#  Timestamp('2023-02-06 00:00:00'),
#  Timestamp('2023-02-13 00:00:00'),
#  Timestamp('2023-02-20 00:00:00'),
#  Timestamp('2023-02-27 00:00:00'),
#  Timestamp('2023-03-06 00:00:00'),
#  Timestamp('2023-03-13 00:00:00'),
#  Timestamp('2023-03-20 00:00:00'),
#  Timestamp('2023-03-27 00:00:00'),
#  Timestamp('2023-04-03 00:00:00'),
#  Timestamp('2023-04-10 00:00:00'),
#  Timestamp('2023-04-17 00:00:00'),
#  Timestamp('2023-04-24 00:00:00'),
#  Timestamp('2023-05-01 00:00:00'),
#  Timestamp('2023-05-08 00:00:00'),
#  Timestamp('2023-05-15 00:00:00'),
#  Timestamp('2023-05-22 00:00:00'),
#  Timestamp('2023-05-29 00:00:00'),
#  Timestamp('2023-06-05 00:00:00'),
#  Timestamp('2023-06-12 00:00:00'),
#  Timestamp('2023-06-19 00:00:00'),
#  Timestamp('2023-06-26 00:00:00')]

# %%
import calendar

# %%
daily_analysis = df.groupby([df['transaction_date'].dt.date,'week_name'])['sales'].sum().reset_index()
avg_daily_analysis = daily_analysis.groupby('week_name')['sales'].mean()
avg_daily_analysis = avg_daily_analysis.reindex(list(calendar.day_name))
display(avg_daily_analysis)
plt.bar(avg_daily_analysis.index,avg_daily_analysis.values,color=['teal','tomato'])
plt.xticks(rotation=45)
# Out:
# week_name
# Monday       3910.664615
# Tuesday      3825.228462
# Wednesday    3858.213077
# Thursday     3875.683846
# Friday       3898.961538
# Saturday     3875.779200
# Sunday       3781.935000
# Name: sales, dtype: float64
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Monday'),
#   Text(1, 0, 'Tuesday'),
#   Text(2, 0, 'Wednesday'),
#   Text(3, 0, 'Thursday'),
#   Text(4, 0, 'Friday'),
#   Text(5, 0, 'Saturday'),
#   Text(6, 0, 'Sunday')])

# %%
hourly_analysis = df.groupby([df.transaction_date.dt.date,'Hour'])['sales'].sum().reset_index()
avg_hourly_analysis = hourly_analysis.groupby('Hour')['sales'].mean()
plt.plot(avg_hourly_analysis.index, avg_hourly_analysis.values,color='navy')

# %%
df.product_category.unique()
# Out:
# array(['Coffee', 'Tea', 'Drinking Chocolate', 'Bakery', 'Flavours',
#        'Loose Tea', 'Coffee beans', 'Packaged Chocolate', 'Branded'],
#       dtype=object)

# %%
Coffee = df[df.product_category =='Loose Tea']
hourly_analysis = Coffee.groupby([Coffee.transaction_date.dt.date,'Hour'])['sales'].sum().reset_index()
avg_hourly_analysis = hourly_analysis.groupby('Hour')['sales'].mean()
plt.plot(avg_hourly_analysis.index, avg_hourly_analysis.values,color='navy')

# %%
for i in df.product_category.unique():
    category = df[df.product_category == i]
    hourly_analysis = category.groupby([category.transaction_date.dt.date,'Hour'])['sales'].sum().reset_index()
    avg_hourly_analysis = hourly_analysis.groupby('Hour')['sales'].mean()
    plt.plot(avg_hourly_analysis.index, avg_hourly_analysis.values,label=i)
    
plt.legend()
plt.show()
plt.savefig('category_hour')

# %%
# Out:
# 0         Sunday
# 1         Sunday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#            ...
# 149111    Friday
# 149112    Friday
# 149113    Friday
# 149114    Friday
# 149115    Friday
# Name: week_name, Length: 149116, dtype: object

# %%
 Total_bevrage = df.groupby('product_type')['sales'].sum().sort_values(ascending=False).reset_index(name='Total_sales').head(5)
Total_bevrage
# Out:
#             product_type  Total_sales
# 0       Barista Espresso     91406.20
# 1        Brewed Chai tea     77081.95
# 2          Hot chocolate     72416.00
# 3  Gourmet brewed coffee     70034.60
# 4       Brewed Black tea     47932.00

# %%
df
# Out:
#         transaction_id transaction_date    transaction_time  transaction_qty  \
# 0                    1       2023-01-01 1900-01-01 07:06:11                2
# 1                    2       2023-01-01 1900-01-01 07:08:56                2
# 2                    3       2023-01-01 1900-01-01 07:14:04                2
# 3                    4       2023-01-01 1900-01-01 07:20:24                1
# 4                    5       2023-01-01 1900-01-01 07:22:41                2
# ...                ...              ...                 ...              ...
# 149111          149452       2023-06-30 1900-01-01 20:18:41                2
# 149112          149453       2023-06-30 1900-01-01 20:25:10                2
# 149113          149454       2023-06-30 1900-01-01 20:31:34                1
# 149114          149455       2023-06-30 1900-01-01 20:57:19                1
# 149115          149456       2023-06-30 1900-01-01 20:57:19                2
#
# ...
